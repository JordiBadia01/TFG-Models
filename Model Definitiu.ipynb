# %% [markdown]
# # Configuració entorn GPU

# %%
import tensorflow as tf
import os

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Càrrega dades

# %%
import cv2
import imghdr

# %%
data_dir_train = r"C:\Users\Nitropc\Desktop\TFG\jpeg_binary\data_balanced_augmented\train"
data_dir_test = r"C:\Users\Nitropc\Desktop\TFG\jpeg_binary\data_balanced_augmented\test"

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
BATCH_SIZE = 2*8  
IMG_SIZE = (128, 128)  

# Càrrega del conjunt de dades d'entrenament
train = tf.keras.utils.image_dataset_from_directory(
    data_dir_train,
    shuffle=True,  # Barreja aleatòria de les mostres després de cada època
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE
)

# Càrrega del conjunt de dades de prova
test = tf.keras.utils.image_dataset_from_directory(
    data_dir_test,
    shuffle=True,  # Barreja aleatòria de les mostres després de cada època
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE
)
# Out:
# Found 50541 files belonging to 2 classes.
# Found 12635 files belonging to 2 classes.

# %%
class_names = train.class_names

plt.figure(figsize=(10, 10))
for images, labels in train.take(1):
  for i in range(BATCH_SIZE):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE  # Constant que permet que TensorFlow automàticament decideixi el millor nombre de threads per processar el conjunt de dades
train_dataset = train.prefetch(buffer_size=AUTOTUNE)  # Optimitza el conjunt de dades d'entrenament
test_dataset = test.prefetch(buffer_size=AUTOTUNE)  # Optimitza el conjunt de dades de prova

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
])

# %%
preprocess_input = tf.keras.applications.efficientnet_v2.preprocess_input

# %%
rescale = tf.keras.layers.Rescaling(1./255)

# %% [markdown]
# # Definició model

# %%
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.efficientnet_v2.EfficientNetV2S(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (16, 4, 4, 1280)

# %%
base_model.summary()
# Out:
# Model: "efficientnetv2-s"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  rescaling_3 (Rescaling)        (None, 128, 128, 3)  0           ['input_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 64, 64, 24)   648         ['rescaling_3[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 64, 64, 24)   96          ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 64, 64, 24)   0           ['stem_bn[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 64, 64, 24)   5184        ['stem_activation[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 64, 64, 24)  96          ['block1a_project_conv[0][0]']
#  lization)
#
#  block1a_project_activation (Ac  (None, 64, 64, 24)  0           ['block1a_project_bn[0][0]']
#  tivation)
#
# ...

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (16, 1280)

# %%
prediction_layer = tf.keras.layers.Dense(1, activation='sigmoid')
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (16, 1)

# %%
inputs = tf.keras.Input(shape=(128, 128, 3))  # Defineix les dimensions de les imatges d'entrada
x = data_augmentation(inputs)  # Aplica augmentació de dades a les imatges d'entrada
x = preprocess_input(x)  # Preprocessa les imatges d'entrada
x = base_model(x, training=False)  # Processa les imatges amb el model de base en mode d'inferència
x = global_average_layer(x)  # Aplica la capa de promig global a les característiques
x = tf.keras.layers.Dropout(0.35)(x)  # Aplica una capa de desactivació per regularitzar el model
outputs = prediction_layer(x)  # Calcula les sortides finals del model
model = tf.keras.Model(inputs, outputs)  # Crea el model utilitzant les capes d'entrada i sortida

# %%
base_learning_rate = 0.00001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  sequential_1 (Sequential)   (None, 128, 128, 3)       0
#
#  efficientnetv2-s (Functiona  (None, 4, 4, 1280)       20331360
#  l)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 1)                 1281
#
# ...
# Total params: 20,332,641
# Trainable params: 20,178,769
# Non-trainable params: 153,872
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 452

# %% [markdown]
# # Entrenament

# %%
initial_epochs = 5

# %%
history = model.fit(train_dataset,
                    epochs=initial_epochs)
# Out:
# Epoch 1/5
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# ...

# %%
acc = history.history['accuracy']
#val_acc = history.history['val_accuracy']

loss = history.history['loss']
#val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
#plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
#plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# # Avaluació

# %%
loss, accuracy = model.evaluate(test_dataset)
# Out:
# 823/823 [==============================] - 153s 38ms/step - loss: 0.0778 - accuracy: 0.9722

# %%
from tensorflow.keras.metrics import Precision, Recall, AUC
pre = Precision()
re = Recall()
auc = AUC()
y_vec = []
yhat_vec = []
for batch in test.as_numpy_iterator(): 
    X, y = batch
    y_vec.append(y)
    #print(y)
    yhat = model.predict(X)
    yhat_vec.append(yhat)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    auc.update_state(y, yhat)
# Out:
# ...
# 1/1 [==============================] - 0s 10ms/step

# %%
print(pre.result(), re.result(), auc.result())
# Out:
# tf.Tensor(0.9823658, shape=(), dtype=float32) tf.Tensor(0.9610687, shape=(), dtype=float32) tf.Tensor(0.9956051, shape=(), dtype=float32)

# %%
precision = 0.9823658
recall = 0.9610687
F1 = 2/((1/precision)+(1/recall))
print(F1)
# Out:
# 0.9716005580125907

# %% [markdown]
# # Guardem el model

# %%
model.save(os.path.join('models','EfficientNetV2S_TEST_C_5.h5'))
